# %% [markdown]
# ## Dosya İşlemleri ##

# %% [markdown]
# ## Dosya Açma(Open) ##
#
# open("dosya_adı","erişim_kipi")
#
# **w erişim kipi** => Dosya yoksa oluştur varsa dosyayı silip yeniden oluşturur.(write kelimesinin kısaltması)

# %%
open("test.txt","w") #bulunduğumuz dizinde dosya oluşturuyoruz.

# %%
file = open("test.txt","w")#dosya üzerinde işlem yapmak için kullandığımız dosya imlecini file değişkenine atadık.

# %%
file.close()#sistem kaynaklarını gereksiz kullanmamak için dosyamızı kapattık.

# %%
file = open("test.txt","w",encoding="utf-8") #Türkçe karakter

# %%
file.write("İsmail")
file.close()

# %% [markdown]
# **a kipi** => Dosya yoksa oluştur varsa sonuna ekle.

# %%
file = open("test.txt","a",encoding="utf-8")
file.write(" Merhaba Dünya")
file.close()

# %%
file = open("test.txt","a",encoding="utf-8")

# %%
file.write("satır 1 \n") #\n bir alt satıra geç

# %%
file.write("Satır 2 \n")

# %%
file.write("Satır 2 \n")

# %%
file.close()

# %% [markdown]
# **Dosya Okuma (r erişim kipi)**
#
# Dosyadan veri okumak için kullanırız.

# %%
file = open("test2.txt","r",encoding="utf-8") 
#dosya bulunamadığı zaman FileNotFoundError hatası alırız.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-30817628222c> in <module>
# ----> 1 file = open("veriler2.txt","r",encoding="utf-8") #Dosya bulunamadığı zaman FileNotFoundError hatası veriyor.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'veriler2.txt'

# %%
try:
    file = open("test.txt","r",encoding="utf-8")
    liste = list(file) #dosyamızdaki değerleri bir listeye aktardık.
    print(liste)
    file.close()
except FileNotFoundError:
    print("Veriler2 dosyası bulunamadı")
print("btk")
# Out:
# ['İsmail Merhaba Dünya Satır 1 \n', 'Satır 1 \n', 'Satır 2 \n']
# btk

# %%
try:
    file = open("test.txt","r",encoding="utf-8")
    for i in file:#for ile test.txt dosyasının içeriğini satır satır yazdırıyoruz.
        print(i,end="")
    file.close()
except FileNotFoundError:
    print("Veriler2 dosyası bulunamadı")
print("btk")

# %% [markdown]
# ## Read Fonksiyonu ##

# %%
file = open("test.txt","r",encoding="utf-8")
txt = file.read()#Dosyanın tamamını okuduk ve dosya imleci dosyanın en sonuna gitti.
file.close()
print(txt)
# Out:
# İsmail Merhaba Dünya Satır 1
# Satır 1
# Satır 2

# %% [markdown]
# ## readline Fonksiyonu ##

# %% [markdown]
# **readline** fonksiyonu her çalıştırıldığında bir satır okunur ve dosya imleci bir sonraki satır başına geçer.

# %%
file = open("test.txt","r",encoding="utf-8")

# %%
print(file.readline())
# Out:
# İsmail Merhaba Dünya Satır 1

# %%
print(file.readline())
# Out:
# Satır 1

# %%
print(file.readline())
# Out:
# Satır 2

# %%
file.close()

# %%
file = open("test.txt","r",encoding="utf-8")
values = file.readlines()#Tüm dosyayı liste halinde verir.
file.close()
print(type(values))
print(values)

# %%
#Bir dosyayı otamatik olarak kapatma
with open("test.txt","r",encoding="utf-8") as file:
    for i in file:
        print(i)

# %% [markdown]
# ## tell Fonksiyonu ##

# %%
with open("test.txt","r",encoding="utf-8") as file:
    print(file.tell())#İmlecin hangi byte üzerinde olduğunu verir.

# %%
with open("test.txt","r",encoding="utf-8") as file:
    file.seek(10)#10. byte'a gidiyoruz.
    print(file.tell())
    veri = file.read(5)
    print(file.tell())
    print(veri)
    veri = file.read(5)
    print(veri)

# %% [markdown]
# ## r+ Erişim Kipi ##

# %% [markdown]
# Hem okuma hem yazma yapmamızı sağlayan erişim kipidir.

# %%
with open("test.txt","r+",encoding = "utf-8") as file: 
    file.seek(10) # 10. byte
    file.write("ismail")
    print(file.tell())
    print(file.readline())
# Out:
# 16
# Dünismailır 1

# %%
with open("test.txt","r+",encoding="utf-8") as file:
    file.write("son")#dosyanın en başına yazar.
    print(file.read())
# Out:
# mail isismailDünismailır 1
# Satır 1
# satır 2ismailismailismail

# %%
#Dosyanın sonuna ekleme yapmak istediğimizde "a" kipini kullanırsak dosya açıldığında dosya imleci en sonda bulunur.
with open("test.txt","a",encoding="utf-8") as file:
    file.write("son\n")

# %% [markdown]
# ## Tkinter ##

# %%
from tkinter import *
window = Tk()
window.title("Hesap Makinesi")
window.mainloop()

# %%
from tkinter import *
window = Tk()
window.title("Hesap Makinesi")
lbl = Label(window, text="Merhaba")
lbl.grid(column=0, row=0)
window.mainloop()

# %%
from tkinter import *
window = Tk()
window.title("Hesap Makinesi")
window.geometry('350x200')
lbl = Label(window, text="Merhaba")
lbl.grid(column=0, row=0)
btn = Button(window, text="Hesapla")
btn.grid(column=0, row=1)
window.mainloop()

# %%
from tkinter import *

def clicked():
    lbl2.configure(text="Butona tıklandı.")

window = Tk()
window.title("Hesap Makinesi")
window.geometry('350x200')
lbl = Label(window, text="Merhaba")
lbl2 = Label(window, text="")
lbl.grid(column=0, row=0)
lbl2.grid(column=0, row=2)
btn = Button(window, text="Tıkla", command=clicked)
btn.grid(column=0, row=1)
window.mainloop()

# %%
from tkinter import *

def clicked():
    lbl2.grid(column=1, row=2)
    lbl2.configure(text="Butona tıklandı.")

window = Tk()
window.title("Hesap Makinesi")
window.geometry('350x200')
lbl = Label(window, text="Merhaba")
lbl2 = Label(window, text="")
lbl.grid(column=1, row=0)
btn = Button(window, text="Tıkla", command=clicked)
btn.grid(column=1, row=1)

txt = Entry(window,width=10)
txt.grid(column=1, row=3)

window.mainloop()

# %%
from tkinter import *

def clicked():
    res = "Hoşgeldin " + txt.get()
    lbl2.configure(text= res)
    lbl2.grid(column=1, row=3)

window = Tk()
window.title("Hesap Makinesi")
window.geometry('350x200')
lbl = Label(window, text="Merhaba")
lbl2 = Label(window, text="")
lbl.grid(column=1, row=0)
btn = Button(window, text="Tıkla", command=clicked)
btn.grid(column=1, row=1)

txt = Entry(window,width=10)
txt.grid(column=1, row=2)

window.mainloop()

# %%
#disabled

from tkinter import *

def clicked():
    txt = Entry(window,width=10)
    txt.grid(column=1, row=2)

window = Tk()
window.title("Hesap Makinesi")
window.geometry('350x200')
lbl = Label(window, text="Merhaba")
lbl.grid(column=1, row=0)
btn = Button(window, text="Tıkla", command=clicked)
btn.grid(column=1, row=1)

#txt = Entry(window,width=10)
txt = Entry(window,width=10, state='disabled')
txt.grid(column=1, row=2)

window.mainloop()

# %%
#combo
from tkinter import *

def clicked():
    res = combo.get()
    lbl.configure(text= res)

window = Tk()
window.title("Deneme")
window.geometry('350x200')

combo = Combobox(window)
combo['values']= (1, 2, 3, 4, 5, "Seç")
combo.current(5) #set the selected item
combo.grid(column=0, row=0)

btn = Button(window, text="Tıkla", command=clicked)
btn.grid(column=1, row=0)

lbl = Label(window, text="Şeç")
lbl.grid(column=2, row=0)


window.mainloop()

# %%
from tkinter import *

def clicked():
    print(chk_state.get())
    if(chk_state.get()):
        print("if")
        chk_state.set(False)
    else:
        print("else")
        chk_state.set(True)

window = Tk()
window.title("Deneme")
window.geometry('350x200')
chk_state = BooleanVar()
chk_state.set(True) #set check state
chk = Checkbutton(window, text='Seç', var=chk_state)
chk.grid(column=0, row=0)

btn = Button(window, text="Tıkla", command=clicked)
btn.grid(column=1, row=0)

window.mainloop()

#chk_state = IntVar()
#chk_state.set(0) #uncheck
#chk_state.set(1) #check
# Out:
# True
# if
# False
# else

# %%
from tkinter import *

def clicked():
    islem = selected.get()
    a = int(txt1.get())
    b = int(txt2.get())
    if(islem == 1):
        cvp = a + b
    elif islem == 2:
        cvp = a-b
    elif islem == 3:
        cvp = a/b
    else:
        cvp = a*b
        
    lbl = Label(window, text="" + str(cvp))
    lbl.grid(column=1, row=3)


window = Tk()
window.title("Hesap Makinesi")
window.geometry('500x500')


txt1 = Entry(window,width=20)
txt1.grid(column=0, row=0)

txt2 = Entry(window,width=20)
txt2.grid(column=2, row=0)

selected = IntVar()
selected.set(2)
rad1 = Radiobutton(window,text='+', value=1, variable=selected)
rad2 = Radiobutton(window,text='-', value=2, variable=selected)
rad3 = Radiobutton(window,text='/', value=3, variable=selected)
rad4 = Radiobutton(window,text="*", value=4, variable=selected)
rad1.grid(column=0, row=1)
rad2.grid(column=1, row=1)
rad3.grid(column=2, row=1)
rad4.grid(column=3, row=1)

btn = Button(window, text="Hesapla", command=clicked)
btn.grid(column=1, row=2)



window.mainloop()

# %% [markdown]
# ## requests ve BeautifulSoup Modülleri (İnternetten Veri Çekme)

# %% [markdown]
# **Kurulum:**

# %% [markdown]
# 1) https://pip.pypa.io/en/latest/installing/ adresine gidiyoruz site içerisindeki
#
#     a) curl https://bootstrap.pypa.io/get-pip.py -o get-pip.py
#
#     b) python get-pip.py\n
#
#     komutlarını konsol(cmd) üzerinde çalıştırarak pip'i kuruyoruz ve sonrasında requests ve BeautifulSoup modullerini
#     pip'i vasıtası ile kuracağız.
#
# 2) requests ve BeautifulSoup modullerinin kurulumu: aşağıdaki komutları konsol(cmd) üzerinde çalıştırıyoruz.
#
#     a) pip3 install requests
#
#     b) pip3 install beautifulsoup4

# %%
import requests 
from bs4 import BeautifulSoup

url =  "https://www.imdb.com/chart/top" # site url 
response =  requests.get(url) # Web sayfasını çekiyoruz.
#print(response)
html_icerigi = response.content  # Web sayfasının içeriğini çekiyoruz.
bSoup =  BeautifulSoup(html_icerigi,"html.parser") # BeautifulSoup nesnesi ile web sitemizi parçalıyoruz.
#print(bSoup)
print(bSoup.prettify()) #prettify metodunu daha güzel bir görüntü almak için kullanıyoruz.

# %%
import requests 
from bs4 import BeautifulSoup

url =  "https://www.imdb.com/chart/top"

response =  requests.get(url)

html_icerigi = response.content
bSoup =  BeautifulSoup(html_icerigi,"html.parser")


#print(soup.find_all("a")) #Tüm <a> etiketlerini liste şeklinde alıyoruz.
for i in bSoup.find_all("a"):#daha düzgün olarak a etiketlerini görüntüleme
    print(i)
    print("***********************************************************************************************************")
# Out:
# <a class="navbarSprite" href="/" id="home_img" title="Home"></a>
# ***********************************************************************************************************
# <a href="/" title="Home">IMDb</a>
# ***********************************************************************************************************
# <a href="/search/">More</a>
# ***********************************************************************************************************
# <a href="/movies-in-theaters/">Movies</a>
# ***********************************************************************************************************
# <a href="/chart/toptv/">TV</a>
# ***********************************************************************************************************
# <a href="/showtimes/">Showtimes</a>
# ***********************************************************************************************************
# <a class="fallback" href="/title/tt0072684/?ref_=nv_mv_dflt_1" title="                            Barry Lyndon
# , #219 on IMDb Top Rated Movies">
# </a>
# ***********************************************************************************************************
# <a href="/title/tt0072684/?ref_=nv_mv_dflt_2" id="titleMenuImageClick">
# <strong>                            Barry Lyndon
# </strong> (1975)
#                                 </a>
# ***********************************************************************************************************
# <a href="/chart/top?ref_=nv_mv_dflt_3" id="titleMenuImageSecondaryClick">
#                                     #<strong>219</strong> on IMDb Top Rated Movies
#                                 </a>
# ***********************************************************************************************************
# <a href="/movies-in-theaters/">In Theaters</a>
# ***********************************************************************************************************
# <a href="/showtimes/">Showtimes &amp; Tickets</a>
# ***********************************************************************************************************
# <a href="/trailers/">Latest Trailers</a>
# ***********************************************************************************************************
# <a href="/movies-coming-soon/">Coming Soon</a>
# ***********************************************************************************************************
# <a href="/calendar/">Release Calendar</a>
# ***********************************************************************************************************
# <a href="/chart/top">Top Rated Movies</a>
# ***********************************************************************************************************
# <a href="/india/top-rated-indian-movies">Top Rated Indian Movies</a>
# ***********************************************************************************************************
# <a href="/chart/moviemeter">Most Popular Movies</a>
# ***********************************************************************************************************
# <a href="/chart/">Box Office</a>
# ***********************************************************************************************************
# <a href="/search/title?count=100&amp;groups=oscar_best_picture_winners&amp;sort=year,desc">Oscar Winners</a>
# ***********************************************************************************************************
# <a href="/genre/">Most Popular by Genre</a>
# ***********************************************************************************************************
# <a href="/chart/toptv/">Top Rated TV Shows</a>
# ***********************************************************************************************************
# <a href="/chart/tvmeter">Most Popular TV Shows</a>
# ***********************************************************************************************************
# <a href="/sections/dvd/">DVD &amp; Blu-Ray</a>
# ***********************************************************************************************************
# <a href="/amazon-originals/">Amazon Originals</a>
# ***********************************************************************************************************
# <a href="/streaming/">Streaming Now</a>
# ***********************************************************************************************************
# <a href="/scary-good/">Horror Guide</a>
# ***********************************************************************************************************
# <a href="/imdbpicks/">IMDb Picks</a>
# ***********************************************************************************************************
# <a href="/originals/">IMDb Original Series</a>
# ***********************************************************************************************************
# <a href="/family-entertainment-guide/">Family Movie/TV Guide</a>
# ***********************************************************************************************************
# <a href="/search/name?gender=male,female">Celebs</a>
# ***********************************************************************************************************
# <a href="/awards-central/">Events</a>
# ***********************************************************************************************************
# <a href="/gallery/rg1859820288">Photos</a>
# ***********************************************************************************************************
# <a class="fallback" href="/name/nm0000234/?ref_=nv_cel_dflt_1" title="Charlize Theron, #106 on STARmeter">
# </a>
# ***********************************************************************************************************
# <a href="/name/nm0000234/?ref_=nv_cel_dflt_2" id="nameAdClick">
# <strong>Charlize Theron</strong>
# </a>
# ***********************************************************************************************************
# <a href="/search/name?birth_monthday=07-24&amp;refine=birth_monthday">Born Today</a>
# ***********************************************************************************************************
# <a href="/news/celebrity">Celebrity News</a>
# ***********************************************************************************************************
# <a href="/search/name?gender=male,female">Most Popular Celebs</a>
# ***********************************************************************************************************
# <a href="/gallery/rg1859820288">Latest Stills</a>
# ***********************************************************************************************************
# <a href="/gallery/rg1624939264">Latest Posters</a>
# ***********************************************************************************************************
# <a href="/gallery/rg1641716480">Photos We Love</a>
# ***********************************************************************************************************
# <a href="/awards-central/">Awards Central</a>
# ***********************************************************************************************************
# <a href="/festival-central/">Festival Central</a>
# ***********************************************************************************************************
# <a href="/oscars/">Oscars</a>
# ***********************************************************************************************************
# <a href="/golden-globes/">Golden Globes</a>
# ***********************************************************************************************************
# <a href="/sundance/">Sundance</a>
# ***********************************************************************************************************
# <a href="/cannes/">Cannes</a>
# ***********************************************************************************************************
# <a href="/comic-con/">San Diego Comic-Con</a>
# ***********************************************************************************************************
# <a href="/emmys/">Emmy Awards</a>
# ***********************************************************************************************************
# <a href="/venice/">Venice Film Festival</a>
# ***********************************************************************************************************
# <a href="/toronto/">Toronto Film Festival</a>
# ***********************************************************************************************************
# <a href="/festival-central/tribeca">Tribeca</a>
# ***********************************************************************************************************
# <a href="/lafilmfest/">LA Film Festival</a>
# ***********************************************************************************************************
# <a href="/event/all/">All Events</a>
# ***********************************************************************************************************
# <a href="/news/top">News</a>
# ***********************************************************************************************************
# <a href="/czone/">Community</a>
# ***********************************************************************************************************
# <a href="/news/ni62558891"> Homecoming: Janelle Monáe to Succeed Julia Roberts in Season 2
# </a>
# ***********************************************************************************************************
# <a href="/news/ni62558783"> Benedict Cumberbatch, Claire Foy Teaming for 'Nine Lives of Louis Wain' for Amazon, StudioCanal
# </a>
# ***********************************************************************************************************
# <a href="/news/ni62558601"> Toronto Film Festival: ‘Joker,’ ‘Ford v Ferrari,’ ‘Hustlers’ Among Big Premieres
# </a>
# ***********************************************************************************************************
# <a href="/news/top">Top News</a>
# ***********************************************************************************************************
# <a href="/news/movie">Movie News</a>
# ***********************************************************************************************************
# <a href="/news/tv">TV News</a>
# ***********************************************************************************************************
# <a href="/news/celebrity">Celebrity News</a>
# ***********************************************************************************************************
# <a href="/news/indie">Indie News</a>
# ***********************************************************************************************************
# <a href="/czone/">Contributor Zone</a>
# ***********************************************************************************************************
# <a href="/poll/">Polls</a>
# ***********************************************************************************************************
# <a href="/list/watchlist">Watchlist</a>
# ***********************************************************************************************************
# <a href="https://pro.imdb.com/login/ap?u=/login/lwa&amp;imdbPageAction=signUp&amp;rf=cons_nb_hm"> <img alt="IMDbPro Menu" src="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_logo_nb._CB484021162_.png"/>
# </a>
# ***********************************************************************************************************
# <a class="imdb-pro-ad__link" href="https://pro.imdb.com/login/ap?u=/login/lwa&amp;imdbPageAction=signUp&amp;rf=cons_nb_hm"> <div class="imdb-pro-ad__image" id="proAd">
# <img alt="Go to IMDbPro" height="145" src="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user._CB484021156_.png" srcset="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user._CB484021156_.png 1x, https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user_2x._CB484021157_.png 2x" width="127"/>
# </div>
# <section class="imdb-pro-ad__content">
# <div class="imdb-pro-ad__title">The essential resource for entertainment professionals</div>
# <p class="imdb-pro-ad__line">Find industry contacts &amp; talent representation</p>
# <p class="imdb-pro-ad__line">Access in-development titles not available on IMDb</p>
# <p class="imdb-pro-ad__line">Get the latest news from leading industry trades</p>
# <p class="imdb-pro-ad__line">Claim your page and control your brand across IMDb &amp; Amazon</p>
# <div class="imdb-pro-new__button">
# <svg height="30px" version="1.1" viewbox="0 0 172 29" width="175px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <title>TryIMDbProFree</title>
# <g fill="none" fill-rule="evenodd" id="tryIMDbProFree" stroke="none" stroke-width="1">
# <rect fill="#F1C241" height="28" id="tryIMDbProFreeButton" rx="3" stroke="#A88734" width="170" x="1" y="1"></rect>
# <text id="tryIMDbProFreeText">
# <tspan x="33" y="19">Try IMDbPro Free</tspan>
# </text>
# </g>
# </svg>
# </div>
# </section>
# </a>
# ***********************************************************************************************************
# <a href="https://help.imdb.com/imdb">Help</a>
# ***********************************************************************************************************
# <a class="nb-social-links__link" href="/offsite/?page-action=fol_fb&amp;token=BCYhJNq-2DqSYylYE5WN6p83gBNr_DVTS64tSlWQo1BmEmIHT0_Jqyg-tNHYZlIHA-kZg8x3ckJY%0D%0A7Kx9VeGLdJnoi7-Bwz5Optr35Euj65sbEVEQ7yibuhAPhBim69_J7kBo81YXYoZ0FwPlCt1zULmx%0D%0AyMNVuJaFWl_NpQCR0WH0THtuqSM9NJI0g9eV5t3M4Dc09TUfvGMiOQBTTNSvbFmnqw%0D%0A" target="_blank" title="Follow IMDb on Facebook"> <svg class="ipl-icon ipl-facebook-icon ipl-icon--inherit-color ipl-icon--inline" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.896 2H3.104C2.494 2 2 2.494 2 3.104v17.792C2 21.506 2.494 22 3.104 22h9.579v-7.745h-2.607v-3.018h2.607V9.01c0-2.584 1.577-3.99 3.882-3.99 1.104 0 2.052.082 2.329.119v2.7h-1.598c-1.254 0-1.496.595-1.496 1.47v1.927h2.989l-.39 3.018h-2.6V22h5.097c.61 0 1.104-.494 1.104-1.104V3.104C22 2.494 21.506 2 20.896 2"></path>
# </svg>
# </a>
# ***********************************************************************************************************
# <a class="nb-social-links__link" href="/offsite/?page-action=fol_inst&amp;token=BCYqJe71nbngWjq_hPBPfMr1JlfCV8lAJ_9bh9W63vRRJrTJHxyp2QCAty0bCKH-BapBRzOtGbAG%0D%0AIYyeLf6YHjBQamTsApQUKTvVtZ3NpxVhAK7z9_uZf2kyr-3i44JoPPg5gzCEEO7JLfxlA40ToBvU%0D%0A4aHg03BEuDkATZyd1Zbvh2XJsl91MYochL98e5OIRUwNL6K6IF0r31sZ7jpeeyu67g%0D%0A" target="_blank" title="Follow IMDb on Instagram"> <svg class="ipl-icon ipl-instagram-icon ipl-icon--inherit-color ipl-icon--inline" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M11.997 2.04c-2.715 0-3.056.011-4.122.06-1.064.048-1.79.217-2.426.463a4.901 4.901 0 0 0-1.771 1.151 4.89 4.89 0 0 0-1.153 1.767c-.247.635-.416 1.36-.465 2.422C2.011 8.967 2 9.307 2 12.017s.011 3.049.06 4.113c.049 1.062.218 1.787.465 2.422a4.89 4.89 0 0 0 1.153 1.767 4.901 4.901 0 0 0 1.77 1.15c.636.248 1.363.416 2.427.465 1.066.048 1.407.06 4.122.06s3.055-.012 4.122-.06c1.064-.049 1.79-.217 2.426-.464a4.901 4.901 0 0 0 1.77-1.15 4.89 4.89 0 0 0 1.154-1.768c.247-.635.416-1.36.465-2.422.048-1.064.06-1.404.06-4.113 0-2.71-.012-3.05-.06-4.114-.049-1.062-.218-1.787-.465-2.422a4.89 4.89 0 0 0-1.153-1.767 4.901 4.901 0 0 0-1.77-1.15c-.637-.247-1.363-.416-2.427-.464-1.067-.049-1.407-.06-4.122-.06m0 1.797c2.67 0 2.985.01 4.04.058.974.045 1.503.207 1.856.344.466.181.8.397 1.15.746.349.35.566.682.747 1.147.137.352.3.88.344 1.853.048 1.052.058 1.368.058 4.032 0 2.664-.01 2.98-.058 4.031-.044.973-.207 1.501-.344 1.853a3.09 3.09 0 0 1-.748 1.147c-.35.35-.683.565-1.15.746-.352.137-.88.3-1.856.344-1.054.048-1.37.058-4.04.058-2.669 0-2.985-.01-4.039-.058-.974-.044-1.504-.207-1.856-.344a3.098 3.098 0 0 1-1.15-.746 3.09 3.09 0 0 1-.747-1.147c-.137-.352-.3-.88-.344-1.853-.049-1.052-.059-1.367-.059-4.031 0-2.664.01-2.98.059-4.032.044-.973.207-1.501.344-1.853a3.09 3.09 0 0 1 .748-1.147c.35-.349.682-.565 1.149-.746.352-.137.882-.3 1.856-.344 1.054-.048 1.37-.058 4.04-.058"></path><path d="M11.997 15.342a3.329 3.329 0 0 1-3.332-3.325 3.329 3.329 0 0 1 3.332-3.326 3.329 3.329 0 0 1 3.332 3.326 3.329 3.329 0 0 1-3.332 3.325m0-8.449a5.128 5.128 0 0 0-5.134 5.124 5.128 5.128 0 0 0 5.134 5.123 5.128 5.128 0 0 0 5.133-5.123 5.128 5.128 0 0 0-5.133-5.124M18.533 6.69c0 .662-.537 1.198-1.2 1.198a1.198 1.198 0 1 1 1.2-1.197"></path>
# </svg>
# </a>
# ***********************************************************************************************************
# <a class="nb-social-links__link" href="/offsite/?page-action=fol_twch&amp;token=BCYgCfQdqG5FDn8wJrmWBnn0Lis4YMlWpqMKjATB3td6drJOy7Dt6L1ERhMwhom90wihshhd_mFu%0D%0AdhpZse2Ze54r6YvLRNh-lxqyeP4K691T32tZRXId31B7tPAUbypk-2F6pLIp1p28UzOKWK-wKSVp%0D%0AwU9aIJ4zTccWOLRzw5bOYOcf7JL58pOaMAY9hOTZoEtJWkbHzvw8QP3MBvmgKxvp-A%0D%0A" target="_blank" title="Follow IMDb on Twitch"> <svg class="ipl-icon ipl-twitch-icon ipl-icon--inherit-color ipl-icon--inline" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <g><path d="M3.40641795,2 L22.0023886,2 L22.0023886,14.8140302 L16.5329854,20.2834333 L12.4700003,20.2834333 L9.81343304,22.9400005 L7.00059714,22.9400005 L7.00059714,20.2834333 L2,20.2834333 L2,5.5941792 L3.40641795,2 Z M20.1271646,13.8764182 L20.1271646,3.87522393 L5.12537321,3.87522393 L5.12537321,17.0017914 L9.34462705,17.0017914 L9.34462705,19.6583587 L12.0011943,17.0017914 L17.0017914,17.0017914 L20.1271646,13.8764182 Z"></path><polygon points="17.0017914 7.46940312 17.0017914 12.9388062 15.1265675 12.9388062 15.1265675 7.46940312"></polygon><polygon points="12.0011943 7.46940312 12.0011943 12.9388062 10.1259704 12.9388062 10.1259704 7.46940312"></polygon></g>
# <path d="M0 0h24v24H0z" fill="none"></path>
# </svg>
# </a>

# <path d="M0 0h24v24H0z" fill="none"></path>
# </svg>
# </a>
# ***********************************************************************************************************
# <a class="ft-social-links__link" href="/offsite/?page-action=fol_tw&amp;token=BCYol0z0a-Od5_VnmHpU1EaRS91Hk1_kMt7405o5wWAfS9tgeEHzVYcCiX1GuIlLRzyaVBIjTqs6%0D%0AnD8Lh2FG4VE-WybMDDvLyvPkhrqrV0gUTJ5zNOeRTAottALj03aYZcYjKqkIlumvhbpPnFgkhvSR%0D%0AgV7AvjqdhPC3QSkLIFtZDWHqLcE6Hv16tF1ZnOgdwQMUSBhaaZSVmHdBUWIingvVFQ%0D%0A" target="_blank" title="Follow IMDb on Twitter"> <svg class="ipl-icon ipl-twitter-icon ipl-icon--inherit-color ipl-icon--inline" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M8.29 19.936c7.547 0 11.675-6.13 11.675-11.446 0-.175-.004-.348-.012-.52A8.259 8.259 0 0 0 22 5.886a8.319 8.319 0 0 1-2.356.633 4.052 4.052 0 0 0 1.804-2.225c-.793.46-1.67.796-2.606.976A4.138 4.138 0 0 0 15.847 4c-2.266 0-4.104 1.802-4.104 4.023 0 .315.036.622.107.917a11.728 11.728 0 0 1-8.458-4.203 3.949 3.949 0 0 0-.556 2.022 4 4 0 0 0 1.826 3.348 4.136 4.136 0 0 1-1.858-.503l-.001.051c0 1.949 1.415 3.575 3.292 3.944a4.193 4.193 0 0 1-1.853.07c.522 1.597 2.037 2.76 3.833 2.793a8.34 8.34 0 0 1-5.096 1.722A8.51 8.51 0 0 1 2 18.13a11.785 11.785 0 0 0 6.29 1.807"></path>
# </svg>
# </a>
# ***********************************************************************************************************
# <a class="ft-social-links__link" href="/offsite/?page-action=fol_yt&amp;token=BCYlg1nvQ5xZcQmNd_F9Kr3p8jCtgnKSn-kpyiUZARVg4yd_eqpwbi7_ZjzmaFKkHXrJbqzL3wTv%0D%0AkxY6XxoEPti8htbSVy5EDpoaAFAiMV8dv3oO5sgbIbLKmIq3__BxWJi1hh-DuC-_DovGmKMLdj6T%0D%0Aaek4IRieHjxjLLkXj91wWQR3c2XS3bmY0_CL6EVdFuQh_o1bhIQsI8yA2Y1YKr-csQ%0D%0A" target="_blank" title="Follow IMDb on YouTube"> <svg class="ipl-icon ipl-youtube-icon ipl-icon--inherit-color ipl-icon--inline" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M9.955 14.955v-5.91L15.182 12l-5.227 2.955zm11.627-7.769a2.505 2.505 0 0 0-1.768-1.768C18.254 5 12 5 12 5s-6.254 0-7.814.418c-.86.23-1.538.908-1.768 1.768C2 8.746 2 12 2 12s0 3.254.418 4.814c.23.86.908 1.538 1.768 1.768C5.746 19 12 19 12 19s6.254 0 7.814-.418a2.505 2.505 0 0 0 1.768-1.768C22 15.254 22 12 22 12s0-3.254-.418-4.814z"></path>
# <path d="M0 0h24v24H0z" fill="none"></path>
# </svg>
# </a>
# ***********************************************************************************************************
# <a href="/">Home</a>
# ***********************************************************************************************************
# <a href="/chart/top">Top Rated Movies</a>
# ***********************************************************************************************************
# <a href="/chart/">Box Office</a>
# ***********************************************************************************************************
# <a href="/movies-coming-soon/">Coming Soon</a>
# ***********************************************************************************************************
# <a href="/a2z">Site Index</a>
# ***********************************************************************************************************
# <a href="/search">Search</a>
# ***********************************************************************************************************
# <a href="/movies-in-theaters/">In Theaters</a>
# ***********************************************************************************************************
# <a href="https://help.imdb.com/imdb">Contact Us</a>
# ***********************************************************************************************************
# <a href="/registration/login">Register</a>
# ***********************************************************************************************************
# <a href="/news/">News</a>
# ***********************************************************************************************************
# <a href="/pressroom/">Press Room</a>
# ***********************************************************************************************************
# <a href="https://advertising.amazon.com/lp/imdb">Advertising</a>
# ***********************************************************************************************************
# <a href="/jobs">Jobs</a>
# ***********************************************************************************************************
# <a href="https://pro.imdb.com/signup/index.html?rf=cons_ft_hm">IMDbPro</a>
# ***********************************************************************************************************
# <a href="/offsite/?page-action=ft-mojo&amp;token=BCYnsUNGSSzLl8qIdgohkLy3maKdqRecjX3qxPeuS7JbjLwEq8_CbpGvCgSQxgcxD-wc-zyqdd5k%0D%0A76kpRzsWGyzkDDM24SIgBQx2CyknMJPB9fDEX9TD_TN7nnvFump-oYKj1IoZYVHvf4YJ7TeEQ2o7%0D%0AyxzTgaIZc4CHrvvkWN-RmKJRU62HqrNKtboXgJS_GSsaVjnCgjV0OYR2pKHRjSVObA%0D%0A">Box Office Mojo</a>
# ***********************************************************************************************************
# <a href="/conditions">Conditions of Use</a>
# ***********************************************************************************************************
# <a href="/privacy">Privacy Policy</a>
# ***********************************************************************************************************
# <a href="/offsite/?page-action=ft-iba&amp;token=BCYp0XTHYUq_7M6Q5gstmvnp_0VgcscxSl4b30DFxw3hhfyCidzg8FKkPb_4rrIetASPx4I2kG9C%0D%0A0-NZc_c1o7DAnGiATrFtrgyVMOoqqVb6K2csSMUXi-8o43KhF5xoZGb8J8O24WEqQdsou3tyael6%0D%0A2e4R9lcEmO9aALOTodq9jhgoN00ffVRCuaJQ9E1JQ1yMtqf-rewm1FbVvsN6n-J-nBrEC4ACnWNQ%0D%0A8tdaKKT2nwQ%0D%0A">Interest-Based Ads</a>
# ***********************************************************************************************************
# <a href="/conditions">Copyright ©</a>
# ***********************************************************************************************************
# <a href="https://help.imdb.com/imdb">IMDb.com, Inc.</a>
# ***********************************************************************************************************
# <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-piv&amp;token=BCYgNKA_RpkPqWGiVsBA354r4sF61Wpi2yzj9q6m5ejHQ7QWoEkpvE0CZvQzbNt36a7RnsrODnbh%0D%0AUnDZ-KUYwot5PjxLVWG4ZdmfLBGisomSzpaDRuePTUHq2Y5bGc0dPM46b7bGttLuD-1IMuY72boS%0D%0A6KgZaeFCNMthp10AwuSormVBqGHH7PGh9-cYX2sWIRNi8zdnRZnn0ODJw5WoDhR13p2iQ4Hk4a33%0D%0AUTN3kxGfS1E%0D%0A">
# <span class="amazon-affiliate-site-name">Prime Video</span><br/>
# <span class="amazon-affiliate-site-desc">Unlimited Streaming<br/>of Movies &amp; TV</span>
# </a>
# ***********************************************************************************************************
# <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-uk&amp;token=BCYhS_XoGSzvasxU1xkIPtA6U7imhbnwVmT2TdUg6hNv4qNF2r966Mv1j0zh4ZJHPFJJj-TXI_c6%0D%0AHBSd6MdYjMqVqvuTKrFbByYX-i65T22Wn9zHv64Vdd-AEBZjV6pIhjIMzkzSIVPgLMHmzJpYOe_m%0D%0AkI8KB9hzJB6pN0woD7xdMJwoEScpe3Vq_qaRqa46cJGANOb6X7VWIOKpIsojqhJU49pNYLbZPQVp%0D%0AY8OGCo1Hxs8%0D%0A">
# <span class="amazon-affiliate-site-name">Amaz
# <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-aud&amp;token=BCYlMrAYUNiD5M9SEnv8ef_sOyG_beQyOAejq1VmECc0JoPYDF2BMzxPDPuc1S6CE2Y61yuozUl4%0D%0AXsqj_az42fPv2uzI-XT6QFM62zgGUdp4-mwyyY7gPXcmGOIDaIYx5KKAKwyKVci4tbQf9XIfatyy%0D%0A0lSKmyc_GFm8ab2bGS_ii6E%0D%0A">
# <span class="amazon-affiliate-site-name">Audible</span><br/>
# <span class="amazon-affiliate-site-desc">Download<br/>Audio Books</span>
# </a>
# ***********************************************************************************************************

# %%
import requests 
from bs4 import BeautifulSoup

url =  "https://www.imdb.com/chart/top"
response =  requests.get(url)
html_icerigi = response.content
bSoup =  BeautifulSoup(html_icerigi,"html.parser")

for i in bSoup.find_all("a"):
    print(i.get("href"))#site içerisindeki a taglarının href özlliklerini alıyoruz.
# Out:
# /
# /
# /search/
# /movies-in-theaters/
# /chart/toptv/
# /showtimes/
# /title/tt0072684/?ref_=nv_mv_dflt_1
# /title/tt0072684/?ref_=nv_mv_dflt_2
# /chart/top?ref_=nv_mv_dflt_3
# /movies-in-theaters/
# /showtimes/
# /trailers/
# /movies-coming-soon/
# /calendar/
# /chart/top
# /india/top-rated-indian-movies
# /chart/moviemeter
# /chart/
# /search/title?count=100&groups=oscar_best_picture_winners&sort=year,desc
# /genre/
# /chart/toptv/
# /chart/tvmeter
# /sections/dvd/
# /amazon-originals/
# /streaming/
# /scary-good/
# /imdbpicks/
# /originals/
# /family-entertainment-guide/
# /search/name?gender=male,female
# /awards-central/
# /gallery/rg1859820288
# /name/nm0000234/?ref_=nv_cel_dflt_1
# /name/nm0000234/?ref_=nv_cel_dflt_2
# /search/name?birth_monthday=07-24&refine=birth_monthday
# /news/celebrity
# /search/name?gender=male,female
# /gallery/rg1859820288
# /gallery/rg1624939264
# /gallery/rg1641716480
# /awards-central/
# /festival-central/
# /oscars/
# /golden-globes/
# /sundance/
# /cannes/
# /comic-con/
# /emmys/
# /venice/
# /toronto/
# /festival-central/tribeca
# /lafilmfest/
# /event/all/
# /news/top
# /czone/
# /news/ni62558891
# /news/ni62558783
# /news/ni62558601
# /news/top
# /news/movie
# /news/tv
# /news/celebrity
# /news/indie
# /czone/
# /poll/
# /list/watchlist
# https://pro.imdb.com/login/ap?u=/login/lwa&imdbPageAction=signUp&rf=cons_nb_hm
# https://pro.imdb.com/login/ap?u=/login/lwa&imdbPageAction=signUp&rf=cons_nb_hm
# https://help.imdb.com/imdb
# /offsite/?page-action=fol_fb&token=BCYphdgrH4tOKQbIOB91ncun2MsLgWSXGb3gkwq__z0mXrOZAtLK43Mwq8jqAyKXnne7Bmrkr986%0D%0ALl5xXoqj3tZIE4cZd_y-P_uNk9jhpnJ15Yd5o28Nx0bgEoFDPVs22pGFWtKzpWKYLONyE2L_HNiU%0D%0ApOAnjIuPae9wt7PzmfzSHpfTwFc2fD8OaXvhjEWGVyqoudFOdIpGIR2lKrwMp0qarA%0D%0A
# /offsite/?page-action=fol_inst&token=BCYlPhc6KrIp0Teb_CYr2u0q0JJZJGe6Vz9hkSEtOQY-1cAh8QwLhJGff4IaICZZ-FSm5mZFGXCb%0D%0AvbTr7otbra1evupVLou417IlIGbUY4NukBSNafN11IRYc4BZOUpXnQWl-TWl5ZxZkKo4jmiULMho%0D%0AhsAqWXUx0VGtfi2k0_WmhA1JrxWDCy1IrupKNLA2qInf_mk0g1djZCW-IvtZvXBy3Q%0D%0A
# /offsite/?page-action=fol_twch&token=BCYnJABQHrFWN66VHbk8QoVb_XH_ftx9UkrCgLdt_kovssO8p9fJp3gzfs0Q28tzCDywjEm483UB%0D%0AogB_3Ql2Tu7qEPdFmJVg06Ln30rOSRqjlTicwdoT0-3sUl4KZFY8rs4UGhRmLzzNcAvTL3Vi31x7%0D%0A4JgXNN1N1Mnnuib2lK9lnkYmx91iTefssPNiraf9wjCjQDYGCIUVMiU_IMFNCMdeRQ%0D%0A
# /offsite/?page-action=fol_tw&token=BCYt5VgG8gY9DMCzvYqC_2MJqynkBaA93zbrp1jTrt6NpWXDOEwRFpLLHpTHXRKM6Zgl27Bx6WuU%0D%0Ah71J1xF9_rZHKZH2rSa0kicFpiZVi5AJt5jViP0z5I--wcu7lM7EOVv59h_bip4RrhwYvmHH7Qj2%0D%0AOjjfs7Zfg30lo0T4b_dRox5OqEE1s27rVw0R2nfgug2j1UkScGSPI8JxMiVb_9dFhw%0D%0A
# /offsite/?page-action=fol_yt&token=BCYgGa6ZvdwuAOjINChwM-i6biZDYHtqAOUr1zY-0rRdpHZnE7he4XG5vG2qfkRLkJAk6rL5J48f%0D%0ACIgDMmqxs90_6Di8YL9wDAdWhhaHuXhQIhOjVbqzDE57dX8jkhvD9lXQS15bESNJjDFrgMLdN1br%0D%0AL9vJYf-jBbZYu2GLBhroA28VhQxltdZMmfqScSMnGiblovdwuClj5Xwpeuhmr3vVnw%0D%0A
# /registration/signin?u=https%3A//www.imdb.com/chart/top
# None
# /title/tt0111161/
# /title/tt0111161/
# /title/tt0068646/
# /title/tt0068646/
# /title/tt0071562/
# /title/tt0071562/
# /title/tt0468569/
# /title/tt0468569/
# /title/tt0050083/
# /title/tt0050083/
# /title/tt0108052/
# /title/tt0108052/
# /title/tt0167260/
# /title/tt0167260/
# /title/tt0110912/
# /title/tt0110912/
# /title/tt0060196/
# /title/tt0060196/
# /title/tt0137523/
# /title/tt0137523/
# /title/tt0120737/
# /title/tt0120737/
# /title/tt0109830/
# /title/tt0109830/
# /title/tt1375666/
# /title/tt1375666/
# /title/tt0080684/
# /title/tt0080684/
# /title/tt0167261/
# /title/tt0167261/
# /title/tt0073486/
# /title/tt0073486/
# /title/tt0099685/
# /title/tt0099685/
# /title/tt0133093/
# /title/tt0133093/
# /title/tt0047478/
# /title/tt0047478/
# /title/tt4154796/
# /title/tt4154796/
# /title/tt0114369/
# /title/tt0114369/
# /title/tt0317248/
# /title/tt0317248/
# /title/tt0076759/
# /title/tt0076759/
# /title/tt0102926/
# /title/tt0102926/
# /title/tt0038650/
# /title/tt0038650/
# /title/tt0118799/
# /title/tt0118799/
# /title/tt0245429/
# /title/tt0245429/
# /title/tt0120815/
# /title/tt0120815/
# /title/tt0114814/
# /title/tt0114814/
# /title/tt0110413/
# /title/tt0110413/
# /title/tt0120689/
# /title/tt0120689/
# /title/tt0816692/
# /title/tt0816692/
# /title/tt0054215/
# /title/tt0054215/
# /title/tt0120586/
# /title/tt0120586/
# /title/tt0021749/
# /title/tt0021749/
# /title/tt0034583/
# /title/tt0034583/
# /title/tt0064116/
# /title/tt0064116/
# /title/tt0253474/
# /title/tt0253474/
# /title/tt0027977/
# /title/tt0027977/
# /title/tt1675434/
# /title/tt1675434/
# /title/tt0407887/
# /title/tt0407887/
# /title/tt0088763/
# /title/tt0088763/
# /title/tt0103064/
# /title/tt0103064/
# /title/tt0110357/
# /title/tt0110357/
# /title/tt2582802/
# /title/tt2582802/
# /title/tt0047396/
# /title/tt0047396/
# /title/tt0172495/
# /title/tt0172495/
# /title/tt0082971/
# /title/tt0082971/
# /title/tt0482571/
# /title/tt0482571/
# /title/tt0078788/
# /title/tt0078788/
# /title/tt0209144/
# /title/tt0209144/
# /title/tt0078748/
# /title/tt0078748/
# /title/tt0095327/
# /title/tt0095327/
# /title/tt0095765/
# /title/tt0095765/
# /title/tt0032553/
# /title/tt0032553/
# /title/tt0043014/
# /title/tt0043014/
# /title/tt4633694/
# /title/tt4633694/
# /title/tt0405094/
# /title/tt0405094/
# /title/tt0057012/
# /title/tt0057012/
# /title/tt4154756/
# /title/tt4154756/
# /title/tt0050825/
# /title/tt0050825/
# /title/tt1853728/
# /title/tt1853728/
# /title/tt0081505/
# /title/tt0081505/
# /title/tt0910970/
# /title/tt0910970/
# /title/tt0119698/
# /title/tt0119698/
# /title/tt0051201/
# /title/tt0051201/
# /title/tt0364569/
# /title/tt0364569/
# /title/tt1345836/
# /title/tt1345836/
# /title/tt0090605/
# /title/tt0090605/
# /title/tt0169547/
# /title/tt0169547/
# /title/tt0087843/
# /title/tt0087843/
# /title/tt2380307/
# /title/tt2380307/
# /title/tt0082096/
# /title/tt0082096/
# /title/tt0033467/
# /title/tt0033467/
# /title/tt0112573/
# /title/tt0112573/
# /title/tt0052357/
# /title/tt0052357/
# /title/tt5311514/
# /title/tt5311514/
# /title/tt0053125/
# /title/tt0053125/
# /title/tt0105236/
# /title/tt0105236/
# /title/tt0086190/
# /title/tt0086190/
# /title/tt0086879/
# /title/tt0086879/
# /title/tt0022100/
# /title/tt0022100/
# /title/tt0180093/
# /title/tt0180093/
# /title/tt0114709/
# /title/tt0114709/
# /title/tt1187043/
# /title/tt1187043/
# /title/tt5074352/
# /title/tt5074352/
# /title/tt0062622/
# /title/tt0062622/
# /title/tt0338013/
# /title/tt0338013/
# /title/tt0986264/
# /title/tt0986264/
# /title/tt0056172/
# /title/tt0056172/
# /title/tt0066921/
# /title/tt0066921/
# /title/tt0045152/
# /title/tt0045152/
# /title/tt0361748/
# /title/tt0361748/
# /title/tt0036775/
# /title/tt0036775/
# /title/tt0211915/
# /title/tt0211915/
# /title/tt0075314/
# /title/tt0075314/
# /title/tt0093058/
# /title/tt0093058/
# /title/tt0119217/
# /title/tt0119217/
# /title/tt0040522/
# /title/tt0040522/
# /title/tt0056592/
# /title/tt0056592/
# /title/tt0012349/
# /title/tt0012349/
# /title/tt0070735/
# /title/tt0070735/
# /title/tt0435761/
# /title/tt0435761/
# /title/tt2106476/
# /title/tt2106476/
# /title/tt0208092/
# /title/tt0208092/
# /title/tt0086250/
# /title/tt0086250/
# /title/tt0053604/
# /title/tt0053604/
# /title/tt0059578/
# /title/tt0059578/
# /title/tt0017136/
# /title/tt0017136/
# /title/tt0071853/
# /title/tt0071853/
# /title/tt0119488/
# /title/tt0119488/
# /title/tt1832382/
# /title/tt1832382/
# /title/tt0097576/
# /title/tt0097576/
# /title/tt1049413/
# /title/tt1049413/
# /title/tt0042876/
# /title/tt0042876/
# /title/tt0042192/
# /title/tt0042192/
# /title/tt0372784/
# /title/tt0372784/
# /title/tt0053291/
# /title/tt0053291/
# /title/tt0055630/
# /title/tt0055630/
# /title/tt0363163/
# /title/tt0363163/
# /title/tt0095016/
# /title/tt0095016/
# /title/tt0105695/
# /title/tt0105695/
# /title/tt0113277/
# /title/tt0113277/
# /title/tt1255953/
# /title/tt1255953/
# /title/tt0040897/
# /title/tt0040897/
# /title/tt0044741/
# /title/tt0044741/
# /title/tt6966692/
# /title/tt6966692/
# /title/tt0081398/
# /title/tt0081398/
# /title/tt0057115/
# /title/tt0057115/
# /title/tt0118849/
# /title/tt0118849/
# /title/tt0457430/
# /title/tt0457430/
# /title/tt0071315/
# /title/tt0071315/
# /title/tt0096283/
# /title/tt0096283/
# /title/tt0347149/
# /title/tt0347149/
# /title/tt0089881/
# /title/tt0089881/
# /title/tt0041959/
# /title/tt0041959/
# /title/tt0055031/
# /title/tt0055031/
# /title/tt0476735/
# /title/tt0476735/
# /title/tt1305806/
# /title/tt1305806/
# /title/tt0015864/
# /title/tt0015864/
# /title/tt0268978/
# /title/tt0268978/
# /title/tt0050212/
# /title/tt0050212/
# /title/tt0112641/
# /title/tt0112641/
# /title/tt0120735/
# /title/tt0120735/
# /title/tt5027774/
# /title/tt5027774/
# /title/tt0050976/
# /title/tt0050976/
# /title/tt0047296/
# /title/tt0047296/
# /title/tt0993846/
# /title/tt0993846/
# /title/tt0080678/
# /title/tt0080678/
# /title/tt2096673/
# /title/tt2096673/
# /title/tt0434409/
# /title/tt0434409/
# /title/tt1979376/
# /title/tt1979376/
# /title/tt0469494/
# /title/tt0469494/
# /title/tt0031679/
# /title/tt0031679/
# /title/tt0477348/
# /title/tt0477348/
# /title/tt1291584/
# /title/tt1291584/
# /title/tt0046912/
# /title/tt0046912/
# /title/tt0083658/
# /title/tt0083658/
# /title/tt3170832/
# /title/tt3170832/
# /title/tt0167404/
# /title/tt0167404/
# /title/tt0050986/
# /title/tt0050986/
# /title/tt0117951/
# /title/tt0117951/
# /title/tt0017925/
# /title/tt0017925/
# /title/tt0031381/
# /title/tt0031381/
# /title/tt0084787/
# /title/tt0084787/
# /title/tt0116282/
# /title/tt0116282/
# /title/tt0091251/
# /title/tt0091251/
# /title/tt8108198/
# /title/tt8108198/
# /title/tt0266543/
# /title/tt0266543/
# /title/tt1205489/
# /title/tt1205489/
# /title/tt0077416/
# /title/tt0077416/
# /title/tt1130884/
# /title/tt1130884/
# /title/tt0118715/
# /title/tt0118715/
# /title/tt0266697/
# /title/tt0266697/
# /title/tt0015324/
# /title/tt0015324/
# /title/tt0061512/
# /title/tt0061512/
# /title/tt0978762/
# /title/tt0978762/
# /title/tt0046438/
# /title/tt0046438/
# /title/tt2119532/
# /title/tt2119532/
# /title/tt0107290/
# /title/tt0107290/
# /title/tt0032976/
# /title/tt0032976/
# /title/tt0892769/
# /title/tt0892769/
# /title/tt2267998/
# /title/tt2267998/
# /title/tt3011894/
# /title/tt3011894/
# /title/tt0120382/
# /title/tt0120382/
# /title/tt0079944/
# /title/tt0079944/
# /title/tt2278388/
# /title/tt2278388/
# /title/tt0107207/
# /title/tt0107207/
# /title/tt0092005/
# /title/tt0092005/
# /title/tt0353969/
# /title/tt0353969/
# /title/tt0018455/
# /title/tt0018455/
# /title/tt0025316/
# /title/tt0025316/
# /title/tt0091763/
# /title/tt0091763/
# /title/tt0758758/
# /title/tt0758758/
# /title/tt0060827/
# /title/tt0060827/
# /title/tt0074958/
# /title/tt0074958/
# /title/tt0052618/
# /title/tt0052618/
# /title/tt0079470/
# /title/tt0079470/
# /title/tt2024544/
# /title/tt2024544/
# /title/tt0405159/
# /title/tt0405159/
# /title/tt0112471/
# /title/tt0112471/
# /title/tt0395169/
# /title/tt0395169/
# /title/tt1392214/
# /title/tt1392214/
# /title/tt1392190/
# /title/tt1392190/
# /title/tt3315342/
# /title/tt3315342/
# /title/tt1028532/
# /title/tt1028532/
# /title/tt1979320/
# /title/tt1979320/
# /title/tt0116231/
# /title/tt0116231/
# /title/tt0046268/
# /title/tt0046268/
# /title/tt0264464/
# /title/tt0264464/
# /title/tt0053198/
# /title/tt0053198/
# /title/tt1895587/
# /title/tt1895587/
# /title/tt0245712/
# /title/tt0245712/
# /title/tt1201607/
# /title/tt1201607/
# /title/tt0060107/
# /title/tt0060107/
# /title/tt0087544/
# /title/tt0087544/
# /title/tt0019254/
# /title/tt0019254/
# /title/tt0093779/
# /title/tt0093779/
# /title/tt0072684/
# /title/tt0072684/
# /title/tt0075148/
# /title/tt0075148/
# /title/tt0169858/
# /title/tt0169858/
# /title/tt0064115/
# /title/tt0064115/
# /title/tt0198781/
# /title/tt0198781/
# /title/tt0405508/
# /title/tt0405508/
# /title/tt0097165/
# /title/tt0097165/
# /title/tt0032551/
# /title/tt0032551/
# /title/tt0088247/
# /title/tt0088247/
# /title/tt4016934/
# /title/tt4016934/
# /title/tt0033870/
# /title/tt0033870/
# /title/tt0113247/
# /title/tt0113247/
# /title/tt0083987/
# /title/tt0083987/
# /title/tt0118694/
# /title/tt0118694/
# /title/tt0246578/
# /title/tt0246578/
# /title/tt1454029/
# /title/tt1454029/
# /title/tt0107048/
# /title/tt0107048/
# /title/tt0032138/
# /title/tt0032138/
# /title/tt2015381/
# /title/tt2015381/
# /title/tt0046911/
# /title/tt0046911/
# /title/tt0073195/
# /title/tt0073195/
# /title/tt0381681/
# /title/tt0381681/
# /title/tt0092067/
# /title/tt0092067/
# /title/tt0325980/
# /title/tt0325980/
# /title/tt0101414/
# /title/tt0101414/
# /title/tt0087884/
# /title/tt0087884/
# /title/tt0101640/
# /title/tt0101640/
# /title/tt0094625/
# /title/tt0094625/
# /title/tt0070047/
# /title/tt0070047/
# /title/tt0072890/
# /title/tt0072890/
# /title/tt0374887/
# /title/tt0374887/
# /title/tt2758880/
# /title/tt2758880/
# https://help.imdb.com/article/imdb/featured-content/why-doesn-t-a-title-with-the-average-user-vote-of-9-4-appear-in-your-top-250-movies-or-tv-list/GTU67Q5QQ8W53RJT
# None
# None
# /chart/boxoffice
# /chart/moviemeter
# /chart/top
# /chart/top-english-movies
# /chart/tvmeter
# /chart/toptv
# /india/top-rated-indian-movies
# /chart/bottom
# None
# /search/title?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=adventure&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=animation&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=biography&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=comedy&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=crime&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=drama&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=family&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=fantasy&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=film_noir&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=history&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=horror&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=music&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=musical&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=mystery&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=romance&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=sci_fi&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=sport&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=thriller&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=war&sort=user_rating,desc&title_type=feature&num_votes=25000,
# /search/title?genres=western&sort=user_rating,desc&title_type=feature&num_votes=25000,
# #
# /offsite/?page-action=ft_app_apple&token=BCYqpR_wrV8cX17v3dcui1lJLdJ0Hv_5f89az_rfinMB3JBmK9K8DiYO5ZG8HUUOdzsuz6DaHZ7B%0D%0A_Ql9BCjXG8Vy4LW6DPSLou2syU7-W5y0WluBS4fDvVF_YQGRKjT7SvQAaqZuln0wq8YG7pKwY_WX%0D%0ApTNuzLg1mWfRfpTu4cb7lFW0GbNPFPmNA6US9h7hAT8JXQsPEkS_FvyFFaDGyIXK4pD6XMoQgzAC%0D%0ApSvOHYpOED4%0D%0A
# /offsite/?page-action=ft_app_google&token=BCYmOFB_zxe697iBlF0kbcLdCa-hIwMezyq5BpGPpJhsLZAjZh-baujsHRpomsJIiewfwZk3KTWX%0D%0AwV2BFxlE_wq782vY7UhNVknWDT6s76B5f62H32YHHOIdokO0B_8m_i9kyvG26Eqeer9hbR7fjEiU%0D%0A1atv8HTnbnGgQ7MBUsTOXYp-XOxOEkgd7BTGchLCANeCMn4lIRx5h4a5Plxd7iw1hn3-4kEvgxwu%0D%0A0-pF3ecI-Is%0D%0A
# /offsite/?page-action=ft_app_amazon&token=BCYi-xa7d6jp-6Srs9laBF7viY4hptM4EERNJ-Vx1LADa0dWbaABA5w2bV54OPcsLhapV5g6KYeS%0D%0AUMUUdYr0hI9KjfDDHkYQDgn9tw89Dx7RnUjBcc4TGJb3VT2t3ERZZA77huNmGlpDzBOGFqZt1obr%0D%0A8TPfcXqlztkeCvd4ijovU-NgjF6VfuRyxdlgJFJKjX6MinxxjxO1HThjJEWqPNIihp15NbLQGbvK%0D%0A2-N0woBtNFCw1QEw0H35eHuGYhrBYdM3yTBoqr0mdD0CFPUYu7trP6UQ0wMYF7nFXwdjwC69ggk%0D%0A
# /offsite/?page-action=ft-amzn-fr&token=BCYp0Esv3-Cji4D-xsnK7023fGIVeG3d9R_a0LyHRB2hRaN0Rs4KLT_nLGu-bG90a4n8qTbJgmjY%0D%0APdNpqTkShW1TWwchIZ2q9JNwwASmwAxTXyD8I6xp6J8kTiVdadbPg27u4tPNSKE9GGNcKIbODD7W%0D%0AQE6bTHdPfv5kJZjWnsnS2G-bUHKHzBof_oJ70EzIW5cDGlrPjLpNG4M-fiAfcF6iJyDtQDDARTNX%0D%0AM8XNDWja6DU%0D%0A
# /offsite/?page-action=ft-amzn-in&token=BCYssMATpr16OqKeyGB0XAiahKsWncszNF9Bz5d-fanaB_zx9_UCH5eW6yO58y0S1MSMIdn-ince%0D%0AKEm1njaH0-wmbO9SMh2sZdjXp4Q5oLybnQVt6_BYKdfMq-noxIrhvpED-eprZ6fqKB3jXVzg1CEk%0D%0A7zXiybHTyF198vpcuttJGz2C1tSPDxA4V-3wdsmbvw9-1RdQrP2pLZcrNaZsjciWTRAjFsFjjidR%0D%0ADqZnSrN4uP5Frb9SuB5O9H0E8DwF1CFx%0D%0A
# /offsite/?page-action=ft-amzn-dpr&token=BCYlBTLPeQtN04HODqr3ISm0eM0neveOh72C89UswA4Olx9AieWFAWHcOUgPE_ROW5B3GMqX12YT%0D%0AEyQyenMCmIaqPwe7An7HqrMA71tyKoWa2TmR1F23SH5nGL5Kx9WHJ0Dne0sYfzd1PVIZx6ut-jWl%0D%0AOqHDlJH4JYTPusoBPt46Qww%0D%0A
# /offsite/?page-action=ft-amzn-aud&token=BCYnh7KhIE_u_yiEAY7dpgAZcYO8jyrSv5q5jN-gDByyJ2I21qvZ3OvHsWT4aCr6jykeEgniaiv3%0D%0AJWHuf2_wXClBo0xEdMGwg_2ggIg-khy3bJYghR_tHpyZqeieETFRro_aF6hKOipOwTJp3hUjqXVK%0D%0AnMvlxZdCv-f2moTvD-gBvtI%0D%0A

# %%
import requests 
from bs4 import BeautifulSoup

url =  "https://www.imdb.com/chart/top" #Site linki
response =  requests.get(url) # Web sayfasını çekiyoruz.
html_icerigi = response.content  # Web sayfasının içeriğini alıyoruz.
bSoup =  BeautifulSoup(html_icerigi,"html.parser") # BeautifulSoup nesnesi ile web sitemizi parçalıyoruz.

for i in bSoup.find_all("a"):
    print(i.text)
# Out:
# IMDb
# More
# Movies
# TV
# Showtimes
#
#
#
#                             Barry Lyndon
#  (1975)
#
#
#                                     #219 on IMDb Top Rated Movies
#
# In Theaters
# Showtimes & Tickets
# Latest Trailers
# Coming Soon
# Release Calendar
# Top Rated Movies
# Top Rated Indian Movies
# Most Popular Movies
# Box Office
# Oscar Winners
# Most Popular by Genre
# Top Rated TV Shows
# Most Popular TV Shows
# DVD & Blu-Ray
# Amazon Originals
# Streaming Now
# Horror Guide
# IMDb Picks
# IMDb Original Series
# Family Movie/TV Guide
# Celebs
# Events
# Photos
#
#
#
# Charlize Theron
#
# Born Today
# Celebrity News
# Most Popular Celebs
# Latest Stills
# Latest Posters
# Photos We Love
# Awards Central
# Festival Central
# Oscars
# Golden Globes
# Sundance
# Cannes
# San Diego Comic-Con
# Emmy Awards
# Venice Film Festival
# Toronto Film Festival
# Tribeca
# LA Film Festival
# All Events
# News
# Community
#  Homecoming: Janelle Monáe to Succeed Julia Roberts in Season 2
#
#  Benedict Cumberbatch, Claire Foy Teaming for 'Nine Lives of Louis Wain' for Amazon, StudioCanal
#
#  Toronto Film Festival: ‘Joker,’ ‘Ford v Ferrari,’ ‘Hustlers’ Among Big Premieres
#
# Top News
# Movie News
# TV News
# Celebrity News
# Indie News
# Contributor Zone
# Polls
# Watchlist
#
#
#
#
#
#
# The essential resource for entertainment professionals
# Find industry contacts & talent representation
# Access in-development titles not available on IMDb
# Get the latest news from leading industry trades
# Claim your page and control your brand across IMDb & Amazon
#
#
# TryIMDbProFree
#
#
#
# Try IMDbPro Free
#
#
#
#
#
#
# Help
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Sign in
#
#
#
#
# The Shawshank Redemption
#
#
# The Godfather
#
#
# The Godfather: Part II
#
#
# The Dark Knight
#
#
# 12 Angry Men
#
#
# Schindler's List
#
#
# The Lord of the Rings: The Return of the King
#
#
# Pulp Fiction
#
#
# Il buono, il brutto, il cattivo
#
#
# Fight Club
#
#
# The Lord of the Rings: The Fellowship of the Ring
#
#
# Forrest Gump
#
#
# Inception
#
#
# Star Wars: Episode V - The Empire Strikes Back
#
#
# The Lord of the Rings: The Two Towers
#
#
# One Flew Over the Cuckoo's Nest
#
#
# Goodfellas
#
#
# The Matrix
#
#
# Shichinin no samurai
#
#
# Avengers: Endgame
#
#
# Se7en
#
#
# Cidade de Deus
#
#
# Star Wars
#
#
# The Silence of the Lambs
#
#
# It's a Wonderful Life
#
#
# La vita è bella
#
#
# Sen to Chihiro no kamikakushi
#
#
# Saving Private Ryan
#
#
# The Usual Suspects
#
#
# Léon
#
#
# The Green Mile
#
#
# Interstellar
#
#
# Psycho
#
#
# American History X
#
#
# City Lights
#
#
# Casablanca
#
#
# Once Upon a Time in the West
#
#
# The Pianist
#
#
# Modern Times
#
#
# The Intouchables
#
#
# The Departed
#
#
# Back to the Future
#
#
# Terminator 2: Judgment Day
#
#
# The Lion King
#
#
# Whiplash
#
#
# Rear Window
#
#
# Gladiator
#
#
# Raiders of the Lost Ark
#
#
# The Prestige
#
#
# Apocalypse Now
#
#
# Memento
#
#
# Alien
#
#
# Hotaru no haka
#
#
# Nuovo Cinema Paradiso
#
#
# The Great Dictator
#
#
# Sunset Blvd.
#
#
# Spider-Man: Into the Spider-Verse
#
#
# The Lives of Others
#
#
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
#
#
# Avengers: Infinity War
#
#
# Paths of Glory
#
#
# Django Unchained
#
#
# The Shining
#
#
# WALL·E
#
#
# Mononoke-hime
#
#
# Witness for the Prosecution
#
#
# Oldeuboi
#
#
# The Dark Knight Rises
#
#
# Aliens
#
#
# American Beauty
#
#
# Once Upon a Time in America
#
#
# Coco
#
#
# Das Boot
#
#
# Citizen Kane
#
#
# Braveheart
#
#
# Vertigo
#
#
# Kimi no na wa.
#
#
# North by Northwest
#
#
# Reservoir Dogs
#
#
# Star Wars: Episode VI - Return of the Jedi
#
#
# Amadeus
#
#
# M - Eine Stadt sucht einen Mörder
#
#
# Requiem for a Dream
#
#
# Toy Story
#
#
# 3 Idiots
#
#
# Dangal
#
#
# 2001: A Space Odyssey
#
#
# Eternal Sunshine of the Spotless Mind
#
#
# Taare Zameen Par
#
#
# Lawrence of Arabia
#
#
# A Clockwork Orange
#
#
# Singin' in the Rain
#
#
# Inglourious Basterds
#
#
# Double Indemnity
#
#
# Amélie
#
#
# Taxi Driver
#
#
# Full Metal Jacket
#
#
# Good Will Hunting
#
#
# Ladri di biciclette
#
#
# To Kill a Mockingbird
#
#
# The Kid
#
#
# The Sting
#
#
# Toy Story 3
#
#
# Jagten
#
#
# Snatch
#
#
# Scarface
#
#
# The Apartment
#
#
# Per qualche dollaro in più
#
#
# Metropolis
#
#
# Monty Python and the Holy Grail
#
#
# L.A. Confidential
#
#
# Jodaeiye Nader az Simin
#
#
# Indiana Jones and the Last Crusade
#
#
# Up
#
#
# Rashômon
#
#
# All About Eve
#
#
# Batman Begins
#
#
# Some Like It Hot
#
#
# Yôjinbô
#
#
# Der Untergang
#
#
# Die Hard
#
#
# Unforgiven
#
#
# Heat
#
#
# Incendies
#
#
# The Treasure of the Sierra Madre
#
#
# Ikiru
#
#
# Green Book
#
#
# Raging Bull
#
#
# The Great Escape
#
#
# Bacheha-Ye aseman
#
#
# Pan's Labyrinth
#
#
# Chinatown
#
#
# Tonari no Totoro
#
#
# Hauru no ugoku shiro
#
#
# Ran
#
#
# The Third Man
#
#
# Judgment at Nuremberg
#
#
# Babam ve Oglum
#
#
# El secreto de sus ojos
#
#
# The Gold Rush
#
#
# A Beautiful Mind
#
#
# The Bridge on the River Kwai
#
#
# Casino
#
#
# Lock, Stock and Two Smoking Barrels
#
#
# Three Billboards Outside Ebbing, Missouri
#
#
# Det sjunde inseglet
#
#
# On the Waterfront
#
#
# The Wolf of Wall Street
#
#
# The Elephant Man
#
#
# Inside Out
#
#
# V for Vendetta
#
#
# Toy Story 4
#
#
# There Will Be Blood
#
#
# Mr. Smith Goes to Washington
#
#
# No Country for Old Men
#
#
# Warrior
#
#
# Dial M for Murder
#
#
# Blade Runner
#
#
# Room
#
#
# The Sixth Sense
#
#
# Smultronstället
#
#
# Trainspotting
#
#
# The General
#
#
# Gone with the Wind
#
#
# The Thing
#
#
# Fargo
#
#
# Idi i smotri
#
#
# Andhadhun
#
#
# Finding Nemo
#
#
# Gran Torino
#
#
# The Deer Hunter
#
#
# Shutter Island
#
#
# The Big Lebowski
#
#
# Kill Bill: Vol. 1
#
#
# Sherlock Jr.
#
#
# Cool Hand Luke
#
#
# Mary and Max
#
#
# Tôkyô monogatari
#
#
# Hacksaw Ridge
#
#
# Jurassic Park
#
#
# Rebecca
#
#
# How to Train Your Dragon
#
#
# Gone Girl
#
#
# Relatos salvajes
#
#
# The Truman Show
#
#
# Stalker
#
#
# The Grand Budapest Hotel
#
#
# In the Name of the Father
#
#
# Stand by Me
#
#
# Salinui chueok
#
#
# Sunrise: A Song of Two Humans
#
#
# It Happened One Night
#
#
# Platoon
#
#
# Into the Wild
#
#
# Persona
#
#
# Network
#
#
# Ben-Hur
#
#
# Life of Brian
#
#
# 12 Years a Slave
#
#
# Million Dollar Baby
#
#
# Before Sunrise
#
#
# Hotel Rwanda
#
#
# Prisoners
#
#
# Mad Max: Fury Road
#
#
# Logan
#
#
# Hachi: A Dog's Tale
#
#
# Rush
#
#
# Eskiya
#
#
# Le salaire de la peur
#
#
# Catch Me If You Can
#
#
# Les quatre cents coups
#
#
# Spotlight
#
#
# Amores perros
#
#
# Harry Potter and the Deathly Hallows: Part 2
#
#
# Andrei Rublev
#
#
# Kaze no tani no Naushika
#
#
# La passion de Jeanne d'Arc
#
#
# The Princess Bride
#
#
# Barry Lyndon
#
#
# Rocky
#
#
# Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni
#
#
# Butch Cassidy and the Sundance Kid
#
#
# Monsters, Inc.
#
#
# Rang De Basanti
#
#
# Dead Poets Society
#
#
# The Grapes of Wrath
#
#
# The Terminator
#
#
# Ah-ga-ssi
#
#
# The Maltese Falcon
#
#
# La haine
#
#
# Gandhi
#
#
# Faa yeung nin wa
#
#
# Donnie Darko
#
#
# The Help
#
#
# Groundhog Day
#
#
# The Wizard of Oz
#
#
# Guardians of the Galaxy
#
#
# Les diaboliques
#
#
# Jaws
#
#
# Before Sunset
#
#
# Tenkû no shiro Rapyuta
#
#
# Pirates of the Caribbean: The Curse of the Black Pearl
#
#
# Beauty and the Beast
#
#
# Paris, Texas
#
#
# Da hong deng long gao gao gua
#
#
# Akira
#
#
# The Exorcist
#
#
# Dog Day Afternoon
#
#
# Munna Bhai M.B.B.S.
#
#
# Kis Uykusu
# Learn more about how list ranking is determined.
#
#
#  Box Office
#  Most Popular Movies
#  Top Rated Movies
#  Top Rated English Movies
#  Most Popular TV
#  Top Rated TV
#  Top Rated Indian Movies
#  Lowest Rated Movies
#
#  Action
#
#  Adventure
#
#  Animation
#
#  Biography
#
#  Comedy
#
#  Crime
#
#  Drama
#
#  Family
#
#  Fantasy
#
#  Film-Noir
#
#  History
#
#  Horror
#
#  Music
#
#  Musical
#
#  Mystery
#
#  Romance
#
#  Sci-Fi
#
#  Sport
#
#  Thriller
#
#  War
#
#  Western
#
# Clear your history
#
#
#
#
#
#
# IMDb Mobile site
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
# Top Rated Movies
# Box Office
# Coming Soon
# Site Index
# Search
# In Theaters
# Contact Us
# Register
# News
# Press Room
# Advertising
# Jobs
# IMDbPro
# Box Office Mojo
# Conditions of Use
# Privacy Policy
# Interest-Based Ads
# Copyright ©
# IMDb.com, Inc.
#
# Prime Video
# Unlimited Streamingof Movies & TV
#
#
# Amazon UK
# Buy Movies onDVD & Blu-ray
#
#
# Amazon Germany
# Buy Movies onDVD & Blu-ray
#
#
# Amazon Italy
# Buy Movies onDVD & Blu-ray
#
#
# Amazon France
# Buy Movies onDVD & Blu-ray
#
#
# Amazon India
# Buy Movie andTV Show DVDs
#
#
# DPReview
# DigitalPhotography
#
#
# Audible
# DownloadAudio Books

# %% [markdown]
# ## Zip Fonksiyonu ##

# %%
liste1 = [1,2,3,4,5,6]
liste2 = [2,4,6,8,10,12]
zipData = list(zip(liste1,liste2))
print(list(zipData))

for i,j in zipData:
    print("i : {}, j: {}".format(i,j))
# Out:
# [(1, 2), (2, 4), (3, 6), (4, 8), (5, 10), (6, 12)]
# i : 1, j: 2
# i : 2, j: 4
# i : 3, j: 6
# i : 4, j: 8
# i : 5, j: 10
# i : 6, j: 12

# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.imdb.com/chart/top"
response = requests.get(url)
html_icerigi = response.content

bSoup = BeautifulSoup(html_icerigi,"html.parser")

a = float(input("Rating'i giriniz:"))

basliklar = bSoup.find_all("td",{"class":"titleColumn"})
ratingler = bSoup.find_all("td",{"class","ratingColumn imdbRating"})

"""
for i in soup.find_all("td",{"class":"titleColumn"}):
    print(i) #print(i.text)
    print("*******************************************************")
"""

# basliklar ve ratingler listelerinin ikisinin de boyutu 250 bu yüzden zip fonk. kullanabiliriz.
#print(len(basliklar),len(ratingler))
for baslik, rating in zip(basliklar,ratingler):
    baslik = baslik.text
    rating = rating.text

    baslik = baslik.strip()
    baslik = baslik.replace("\n","")

    rating = rating.strip()
    rating = rating.replace("\n","")

    if (float(rating) > a): #Kulllanıcının girdiği rating den büyükse yazdır dedik.
        print("Film ismi: {} Filmin Ratingi : {}".format(baslik,rating))
# Out:
# Rating'i giriniz:5
# Film ismi: 1.      The Shawshank Redemption(1994) Filmin Ratingi : 9.2
# Film ismi: 2.      The Godfather(1972) Filmin Ratingi : 9.2
# Film ismi: 3.      The Godfather: Part II(1974) Filmin Ratingi : 9.0
# Film ismi: 4.      The Dark Knight(2008) Filmin Ratingi : 9.0
# Film ismi: 5.      12 Angry Men(1957) Filmin Ratingi : 8.9
# Film ismi: 6.      Schindler's List(1993) Filmin Ratingi : 8.9
# Film ismi: 7.      The Lord of the Rings: The Return of the King(2003) Filmin Ratingi : 8.9
# Film ismi: 8.      Pulp Fiction(1994) Filmin Ratingi : 8.9
# Film ismi: 9.      Il buono, il brutto, il cattivo(1966) Filmin Ratingi : 8.8
# Film ismi: 10.      Fight Club(1999) Filmin Ratingi : 8.8
# Film ismi: 11.      The Lord of the Rings: The Fellowship of the Ring(2001) Filmin Ratingi : 8.8
# Film ismi: 12.      Forrest Gump(1994) Filmin Ratingi : 8.7
# Film ismi: 13.      Inception(2010) Filmin Ratingi : 8.7
# Film ismi: 14.      Star Wars: Episode V - The Empire Strikes Back(1980) Filmin Ratingi : 8.7
# Film ismi: 15.      The Lord of the Rings: The Two Towers(2002) Filmin Ratingi : 8.7
# Film ismi: 16.      One Flew Over the Cuckoo's Nest(1975) Filmin Ratingi : 8.7
# Film ismi: 17.      Goodfellas(1990) Filmin Ratingi : 8.7
# Film ismi: 18.      The Matrix(1999) Filmin Ratingi : 8.6
# Film ismi: 19.      Shichinin no samurai(1954) Filmin Ratingi : 8.6
# Film ismi: 20.      Avengers: Endgame(2019) Filmin Ratingi : 8.6
shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni(1997) Filmin Ratingi : 8.0
# Film ismi: 222.      Butch Cassidy and the Sundance Kid(1969) Filmin Ratingi : 8.0
# Film ismi: 223.      Monsters, Inc.(2001) Filmin Ratingi : 8.0
# Film ismi: 224.      Rang De Basanti(2006) Filmin Ratingi : 8.0
# Film ismi: 225.      Dead Poets Society(1989) Filmin Ratingi : 8.0
# Film ismi: 226.      The Grapes of Wrath(1940) Filmin Ratingi : 8.0
# Film ismi: 227.      The Terminator(1984) Filmin Ratingi : 8.0
# Film ismi: 228.      Ah-ga-ssi(2016) Filmin Ratingi : 8.0
# Film ismi: 229.      The Maltese Falcon(1941) Filmin Ratingi : 8.0
# Film ismi: 230.      La haine(1995) Filmin Ratingi : 8.0
# Film ismi: 231.      Gandhi(1982) Filmin Ratingi : 8.0
# Film ismi: 232.      Faa yeung nin wa(2000) Filmin Ratingi : 8.0
# Film ismi: 233.      Donnie Darko(2001) Filmin Ratingi : 8.0
# Film ismi: 234.      The Help(2011) Filmin Ratingi : 8.0
# Film ismi: 235.      Groundhog Day(1993) Filmin Ratingi : 8.0
# Film ismi: 236.      The Wizard of Oz(1939) Filmin Ratingi : 8.0
# Film ismi: 237.      Guardians of the Galaxy(2014) Filmin Ratingi : 8.0
# Film ismi: 238.      Les diaboliques(1955) Filmin Ratingi : 8.0
# Film ismi: 239.      Jaws(1975) Filmin Ratingi : 8.0
# Film ismi: 240.      Before Sunset(2004) Filmin Ratingi : 8.0
# Film ismi: 241.      Tenkû no shiro Rapyuta(1986) Filmin Ratingi : 8.0
# Film ismi: 242.      Pirates of the Caribbean: The Curse of the Black Pearl(2003) Filmin Ratingi : 8.0
# Film ismi: 243.      Beauty and the Beast(1991) Filmin Ratingi : 8.0
# Film ismi: 244.      Paris, Texas(1984) Filmin Ratingi : 8.0
# Film ismi: 245.      Da hong deng long gao gao gua(1991) Filmin Ratingi : 8.0
# Film ismi: 246.      Akira(1988) Filmin Ratingi : 8.0
# Film ismi: 247.      The Exorcist(1973) Filmin Ratingi : 8.0
# Film ismi: 248.      Munna Bhai M.B.B.S.(2003) Filmin Ratingi : 8.0
# Film ismi: 249.      Dog Day Afternoon(1975) Filmin Ratingi : 8.0
# Film ismi: 250.      Kis Uykusu(2014) Filmin Ratingi : 8.0

# %%
import requests 
from bs4 import BeautifulSoup

url =  "https://kur.doviz.com/serbest-piyasa/amerikan-dolari" # Site linkimiz 

response =  requests.get(url) # Web sayfamızı çekiyoruz.
html_icerigi = response.content  # Web sayfamızın içeriğini alıyoruz.

bSoup =  BeautifulSoup(html_icerigi,"html.parser") # Web sayfamızı parçalamak için BeautifulSoup objesine atıyoruz.
#print(bSoup)
#print(bSoup.prettify()) # Daha güzel bir görüntü için prettify() fonksiyonunu kullanıyoruz.   kur-title

liste = list()
for i in bSoup.find_all("div",{"class":"col"}):
    #print(i)
    for j in i.find_all("span"):
        liste.append(j.text)
        print(j.text)
        
print(liste)
print("Alış:", liste[1])
# Out:
# Alış
# 5,7269
# Satış
# 5,7241
# % 0,13
#
# Son Güncelleme: 10:52
# ['Alış', '5,7269', 'Satış', '5,7241', '% 0,13', '', 'Son Güncelleme: 10:52']
# Alış: 5,7269
